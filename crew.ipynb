# %% [markdown]
# **Imports & Setup**

# %%
import os
import litellm
from dotenv import load_dotenv

# Disable CrewAI Telemetry (Prevents hanging at the end)
os.environ["CREWAI_TELEMETRY_OPT_OUT"] = "true"

# Disable LiteLLM background threads (Prevents hanging)
litellm.telemetry = False
litellm.success_callback = []
litellm.failure_callback = []

# Import CrewAI components
from crewai import Agent, Task, Crew, LLM

# Load environment variables
load_dotenv()
# Out:
# True

# %% [markdown]
# **Initialize Groq LLM**

# %%
# Initialize Groq (Llama 3.3 70B)
llm = LLM(
    model="groq/llama-3.3-70b-versatile",
    temperature=0.1
)

# Quick connection test
print(f"Connection Test: {llm.call('Hello')}")
# Out:
# Connection Test: Hello. It's nice to meet you. Is there something I can help you with or would you like to chat?

# %% [markdown]
# **Define Agents & Tasks**

# %%
# --- Agents ---

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    verbose=True,
    llm=llm,
    max_rpm=10  # <--- Safety limit for Groq Free Tier
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    verbose=True,
    llm=llm,
    max_rpm=10  # <--- Safety limit for Groq Free Tier
)

# --- Tasks ---

task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic}.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1] # This passes the output of task1 to task2
)

# --- Crew ---

crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose=True
)

# %% [markdown]
# **Execute Workflow**

# %%
topic = "The future of electrical vehicles"
result = crew.kickoff(inputs={"topic": topic})

print("\n\n########################")
print("## Final Blog Post ##")
print("########################\n")
print(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 37a67877-70b9-43cd-b221-e83985034f22                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  * By 2040, it's estimated that over 50% of all new car sales will be electric vehicles (EVs), with many        │
# │  countries investing heavily in EV infrastructure and incentivizing their adoption to reduce greenhouse gas     │
# │  emissions and meet climate goals.                                                                              │
# │  * Solid-state batteries are being developed to replace traditional lithium-ion batteries in EVs, promising     │
# │  faster charging times, longer ranges, and improved safety, with several companies already announcing plans to  │
# │  start production in the next few years.                                                                        │
# │  * The future of EVs is also expected to be shaped by advancements in autonomous driving technology, with many  │
# │  manufacturers planning to integrate self-driving capabilities into their EV models, enabling features like     │
# │  vehicle-to-everything (V2X) communication and enhanced safety features.                                        │
# │  * Wireless charging technology is being developed to make charging EVs even more convenient, with companies    │
# │  like WiTricity and Plugless already demonstrating high-power wireless charging systems that can charge         │
# │  vehicles at rates of up to 11 kW.                                                                              │
# │  * The European Union has set a goal of having at least 30 million EVs on the road by 2030, with many member    │
# │  states offering incentives like tax breaks, free parking, and access to bus lanes to encourage the adoption    │
# │  of EVs and reduce air pollution in urban areas.                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 9604c388-11b5-4c0a-8949-12191921bd21                                                                     │
# │  Agent: Research Specialist                                                                                     │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The future of electrical vehicles is looking bright, with over 50% of new car sales expected to be EVs by      │
# │  2040. Solid-state batteries are being developed to replace traditional lithium-ion batteries, promising        │
# │  faster charging times and longer ranges. Autonomous driving technology is also expected to shape the future    │
# │  of EVs, with many manufacturers planning to integrate self-driving capabilities into their models.             │
# │  Additionally, wireless charging technology is being developed to make charging EVs more convenient. With the   │
# │  European Union aiming for at least 30 million EVs on the road by 2030, the adoption of EVs is expected to      │
# │  reduce greenhouse gas emissions and air pollution in urban areas, creating a more sustainable transportation   │
# │  system.                                                                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ########################
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 116fa279-292e-4ca0-b186-51c9931daae7                                                                     │
# │  Agent: Creative Writer                                                                                         │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
